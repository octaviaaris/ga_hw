# %% [markdown]
# ## 2013 Club Championship Stats

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
stats = pd.read_html('../data/2013ClubChampStats.html')

# %%
stats_13 = stats[0]
stats_13.head()
# Out:
#    Team Number             Name  Goal  Assist  D  TO
# 0  Bent      0  Brittany Kaplan     0       3  2   5
# 1  Bent      1        Lexi Zalk     4       1  4   0
# 2  Bent      2     Karen Chalif     3       1  0   6
# 3  Bent      3      Judy Jarvis     3       7  2  11
# 4  Bent      5   Katherine Cole     1       1  1   2

# %%
stats_13.rename(columns={'Player':'Name', 'No.':'Number', 'Goals':'Goal', 'Assists':'Assist', 'Ds':'D', 'TOs':'TO'}, inplace=True)

# %% [markdown]
# ## 2014 Club Championship Stats

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_team_stat_urls(Championship_Page_URL):
    import requests
    from bs4 import BeautifulSoup
    
    r = requests.get(Championship_Page_URL) 
    b = BeautifulSoup(r.text, 'html.parser')

    step1 = [str(item).split('\n') for item in b.find_all('tr', style='border: 1px solid #eee;')]
    step2 = [item[1][13:-9] for item in step1]
    step3 = [item.split('">') for item in step2]
    step4 = [item[1].split(' (') for item in step3]
    
    dict_name = {}
    
    for item in range(16):
        dict_name[step4[item][0]] = step3[item][0] 
    
    return dict_name

# %%
teams_2014 = get_team_stat_urls('http://play.usaultimate.org/events/USA-Ultimate-National-Championships/schedule/Women/Club-Women/')

# %%
teams_2014
# Out:
# {'Brute Squad': '/events/teams/?EventTeamId=xp%2bejIJBOcfXXkdUBdhyKw7QdaKTsy2msZaYJsN0QFI%3d',
#  'Capitals': '/events/teams/?EventTeamId=QMEULDssKTN4OuwrBMNq94efa7qxYCOB39XjXXvDBuY%3d',
#  'Fury': '/events/teams/?EventTeamId=CBkbxJkqtPUazzlNKxrMYL476TAvWyT%2b%2bII9vIya7AM%3d',
#  'Green Means Go': '/events/teams/?EventTeamId=ejfj3ptI1RiAMMNBDBMR%2bOWMPBwsN0Y86S%2fuCAYPw9U%3d',
#  'Heist': '/events/teams/?EventTeamId=h%2bkaG2ZXhVd798X3lGV7PeEc5SUIuvMgQy9BNMokNsM%3d',
#  'Molly Brown': '/events/teams/?EventTeamId=cKqY9nt%2bZuiYvmdlJ2MwdG0cK1L9yUN%2bWnowMqR1zKg%3d',
#  'Nemesis': '/events/teams/?EventTeamId=mIbs2PBWcyioQl2JAuLt1FjcCr3eIAK7iEJX3hRzIO8%3d',
#  'Nightlock': '/events/teams/?EventTeamId=KWGXFcYyimfQtEQ%2fDYoEE7kZ1HzzEC0yN7KIfYlhSWg%3d',
#  'Ozone': '/events/teams/?EventTeamId=01oilPzTzWp6xnsGkQ0uJtZl64NEdUOHJ0wQZrvMnNY%3d',
#  'Riot': '/events/teams/?EventTeamId=ddLOZCRcEzHqNrt1jat3nz4wNJ%2f7YNKK5OZQonhRuaQ%3d',
#  'Scandal': '/events/teams/?EventTeamId=m%2f3%2f0BtHZz5iI3aEgO1fqtpMAlDOwL7dnQ9uEQk0EK8%3d',
#  'Schwa': '/events/teams/?EventTeamId=esap3%2bfn3sLLAi%2bd1CxTiw7BVTCxjkAJdsoGTOIgx%2bc%3d',
#  'Showdown': '/events/teams/?EventTeamId=i9PHtiZOwQbftmahwj7ZWJSPQInr4SNYpfhAUtOB3xo%3d',
#  'Tabby Rosa': '/events/teams/?EventTeamId=BsdQC%2fDwobEqjntQ3M%2bPsGxZBLsy7MKdvHHcjWZszdU%3d',
#  'Traffic': '/events/teams/?EventTeamId=lz7rHLVbDRM0KJ9kdEdQCmulguSFhgEyLZE8x%2fjkm5A%3d',
#  'Underground': '/events/teams/?EventTeamId=3sDF4XVM1iwycJyXOa%2fItCAuNm%2b40z%2bEJPmAfa7S2BA%3d'}

# %%
# explore existing columns

r = requests.get('http://play.usaultimate.org' + teams_2014['Traffic']) #any team name will do
team_page = BeautifulSoup(r.text, 'html.parser')

# %%
columns_2014 = [str(item)[15:-5] for item in team_page.find('div', id='roster_list').find_all('th', span='col')]

# %%
columns_2014
# Out:
# ['No.',
#  'Name',
#  'Position',
#  'Year',
#  'Height',
#  'Goals',
#  'Assists',
#  'Ds',
#  'Turns']

# %%
def get_stats_page(team_name, dict_name):
    # get html of team stats page
    r = requests.get('http://play.usaultimate.org' + dict_name[team_name])
    team_page = BeautifulSoup(r.text, 'html.parser')
    return team_page.find('div', id='roster_list')

# %%
def player_info(team_name, dict_name):
    
    List1 = [str(item)[4:-5] for item in get_stats_page(team_name, dict_name).find_all('td')]
    
    playerInfo = []
    count = 0
    
    while count < len(List1):
        
        info = {}

        info['No.'] = List1[count]
        info['Name'] = List1[count+1]
#         info['Position'] = List1[count+2]
#         info['Year'] = List1[count+3]
#         info['Height'] = List1[count+4]
        info['Goals'] = int(List1[count+5])
        info['Assists'] = int(List1[count+6])
        info['Ds'] = int(List1[count+7])
        info['Turns'] = int(List1[count+8])
        info['Team'] = team_name
        
        count += 9
        playerInfo.append(info)
    
    return playerInfo

# %%
def get_stats(dict_name):
    stats = []

    for team in dict_name:
        stats += player_info(str(team), dict_name)
    
    return stats

# %%
import numpy as np
from pandas import DataFrame, Series

stats_14 = DataFrame.from_dict(get_stats(teams_2014))

# %%
cols = ['Team', 'No.', 'Name', 'Goals', 'Assists', 'Ds', 'Turns']
stats_14 = stats_14[cols]

# %%
stats_14.head()
# Out:
#         Team No.           Name  Goals  Assists  Ds  Turns
# 0  Nightlock  00     KARA KELLY      0        0   0      0
# 1  Nightlock  01   SHARON TSENG      2        2   0      0
# 2  Nightlock  02  MARISA RAFTER      5        7   0      0
# 3  Nightlock  03   MICHAELA LEE      3        3   0      0
# 4  Nightlock  04  MARIKA AUSTIN      3        5   0      0

# %%
stats_14.dtypes
# Out:
# Team       object
# No.        object
# Name       object
# Goals       int64
# Assists     int64
# Ds          int64
# Turns       int64
# dtype: object

# %%
stats_14[stats_14.Team == 'Scandal'].sort_values('Goals', ascending=False).head() # sort not working for goals/assists
# Out:
#         Team No.                Name  Goals  Assists  Ds  Turns
# 338  Scandal  37    SANDRA JORGENSEN     21        4   0      0
# 333  Scandal  19        ALICIA WHITE     10        5   0      0
# 323  Scandal  04          SARAH ITOH      8        4   0      0
# 325  Scandal  06  ASHLEY DALY MORGAN      7        3   0      0
# 326  Scandal  07      KIMBERLY BEACH      7        2   0      0

# %% [markdown]
# ## 2015 Club Championship Stats

# %%
teams_2015 = get_team_stat_urls('http://play.usaultimate.org/events/USA-Ultimate-National-Championships-2015/schedule/Women/Club-Women/')

# %%
teams_2015
# Out:
# {'BENT': '/events/teams/?EventTeamId=tl1rkVLjdczXVbOWzjG8T6fVjubOyhxGoQqAHV0da4g%3d',
#  'Brute Squad': '/events/teams/?EventTeamId=c%2bbyh9S9ANQUYGFX55jj2huoFtowEZg%2fAyga4pprMQ0%3d',
#  'Capitals': '/events/teams/?EventTeamId=x4u7Gvp5rOjImw437isTD%2fs%2bQ06953u7JY%2f95O2ZmYY%3d',
#  'Fury': '/events/teams/?EventTeamId=32oHgC3wTopGTV3EhDSbH36OX0nyemEg%2bP5KQfBRE1g%3d',
#  'Heist': '/events/teams/?EventTeamId=CpQQbzcjJ0UXcqhrXjm3d8zVp0%2fIhQBVr%2fCVAX8yEAY%3d',
#  'Iris': '/events/teams/?EventTeamId=Wy3HoIVoyiewP6W0uRSYiIJo8RJY0m3zrLvGpRwtEwI%3d',
#  'Molly Brown': '/events/teams/?EventTeamId=RbDtI%2bYRGJIFXwMyY2GXHZNkAP4TG3e5cYp%2bwYagX5s%3d',
#  'Nemesis': '/events/teams/?EventTeamId=crhCXpLrJODvUJL6ppk9K1V8i2mXHNLATKv1ZOibPUc%3d',
#  'Nightlock': '/events/teams/?EventTeamId=EfdvGasY6mEwfXfzbwlKQKOo3de2IF4mbYrPHnmtd2Q%3d',
#  'Ozone': '/events/teams/?EventTeamId=iAImqQuifQ77w%2bC0P2niH56jBIDV%2fpmjWfCpaiDP%2brQ%3d',
#  'Phoenix': '/events/teams/?EventTeamId=CB%2br3JHfJtcIvZONww0nNVHSZZMq9jH%2frilvqOvHLyk%3d',
#  'Scandal': '/events/teams/?EventTeamId=1p1xfsPWLSJo49m2wW6PLGWhf64z3TbBK80VQYupjH4%3d',
#  'Schwa': '/events/teams/?EventTeamId=tVfG9QyqwGVHTA9%2bJr5%2f2OCqzoOVdKoauqT3wHzADl8%3d',
#  'Seattle Riot': '/events/teams/?EventTeamId=rL6ZybguUwJ2d26MOqTQkrgsVAuQwZmdj07a9vAJNiY%3d',
#  'Showdown': '/events/teams/?EventTeamId=2rKdDwlJsGvedI6QGcXrsJNiSoqMED%2fY0ah5QVEvfuU%3d',
#  'Traffic': '/events/teams/?EventTeamId=b6KwKgl3XZF4UGZSITU4rrdMUuX4kEWeE%2fOrNp3ceDg%3d'}

# %%
stats_15 = DataFrame.from_dict(get_stats(teams_2015))

# %%
stats_15 = stats_15[cols]

# %%
stats_13.head()
# Out:
#    Team Number             Name  Goal  Assist  D  TO
# 0  Bent      0  Brittany Kaplan     0       3  2   5
# 1  Bent      1        Lexi Zalk     4       1  4   0
# 2  Bent      2     Karen Chalif     3       1  0   6
# 3  Bent      3      Judy Jarvis     3       7  2  11
# 4  Bent      5   Katherine Cole     1       1  1   2

# %%
stats_14.rename(columns={'No.':'Number', 'Goals':'Goal', 'Assists':'Assist', 'Ds':'D', 'Turns':'TO'}, inplace=True)
stats_14.head()
# Out:
#         Team Number           Name  Goal  Assist  D  TO  Team_num
# 0  Nightlock     00     KARA KELLY     0       0  0   0       NaN
# 1  Nightlock     01   SHARON TSENG     2       2  0   0       NaN
# 2  Nightlock     02  MARISA RAFTER     5       7  0   0       NaN
# 3  Nightlock     03   MICHAELA LEE     3       3  0   0       NaN
# 4  Nightlock     04  MARIKA AUSTIN     3       5  0   0       NaN

# %%
stats_15.rename(columns={'No.':'Number', 'Goals':'Goal', 'Assists':'Assist', 'Ds':'D', 'Turns':'TO'}, inplace=True)
stats_15.head()
# Out:
#    Team Number                   Name  Goal  Assist  D  TO
# 0  Iris     00       CAROLINE CADOTTE     0       0  0   0
# 1  Iris     00         MARIANNE PILON     0       0  0   0
# 2  Iris     00  Stéphanie  Villanueva     0       0  0   0
# 3  Iris     01           JULIE DAVIAU     9       1  4   8
# 4  Iris     04           MARIE GENEST     6      19  1  18

# %% [markdown]
# ## 2012 WUGC Stats

# %% [markdown]
# ## 2013 WG Stats

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('http://results.wfdf.org/?view=teamcard&Team=1469') 
b = BeautifulSoup(r.text, 'html.parser')

b.find('table')
# step1 = [str(item).split('\n') for item in b.find_all('tr', style='border: 1px solid #eee;')]
# step2 = [item[1][13:-9] for item in step1]
# step3 = [item.split('">') for item in step2]
# step4 = [item[1].split(' (') for item in step3]

# dict_name = {}

# for item in range(16):
#     dict_name[step4[item][0]] = step3[item][0] 

# return dict_name
# Out:
# <table border="0" cellpadding="0" cellspacing="0" style="width:100%;white-space: nowrap;"><tr>\n<td class="topheader_left">\n<a class="header_text" href="http://www.wfdf.org"><img alt="WFDF" class="header_logo" src="cust/wfdf/logo.jpg" style="width:550px;height:50px"/></a><br/>\n</td><td class="topheader_right"><table border="0" cellpadding="0" cellspacing="0" style="width:95%;white-space: nowrap;">\n<tr><td class="right" style="vertical-align:top;"><a href="?view=teamcard&amp;Team=1469&amp;locale=en_GB.utf8"><img alt="en_GB.utf8" class="localeselection" src="locale/en_GB.utf8/flag.png"/></a>\n<a href="?view=teamcard&amp;Team=1469&amp;locale=fi_FI.utf8"><img alt="fi_FI.utf8" class="localeselection" src="locale/fi_FI.utf8/flag.png"/></a>\n</td></tr><tr>\n<td class="right" style="padding-top:5px"><input class="input" id="myusername" name="myusername" size="10" style="border:1px solid #555555" type="text"/>\xa0<input class="input" id="mypassword" name="mypassword" size="10" style="border:1px solid #555555" type="password"/>\xa0<input class="button" name="login" style="border:1px solid #000000" type="submit" value="Login"/>\xa0<span class="topheadertext"><a class="topheaderlink" href="?view=register">New user?</a></span></td></tr>\n</table></td></tr></table>

# %% [markdown]
# ## 2014 WUCC

# %%
# stats_15.Team

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.boxplot(x="Team",y="Goals",data=stats_13)

# %%
sns.boxplot(x="Team",y="Goals",data=stats_13[(stats_13.Team == 'Fury') | (stats_13.Team == 'Riot') | (stats_13.Team == 'Scandal')])

# %%
sns.boxplot(x="Team",y="Assists",data=stats_13[(stats_13.Team == 'Fury') | (stats_13.Team == 'Riot') | (stats_13.Team == 'Scandal')])

# %%
sns.boxplot(x="Team",y="Ds",data=stats_13[(stats_13.Team == 'Fury') | (stats_13.Team == 'Riot') | (stats_13.Team == 'Scandal')])

# %%
sns.boxplot(x="Team",y="TOs",data=stats_13[(stats_13.Team == 'Fury') | (stats_13.Team == 'Riot') | (stats_13.Team == 'Scandal')])

# %%
sns.distplot(stats_13[stats_13.Team == 'Fury'].Ds,  rug=True)

# %%
sns.distplot(stats_13[stats_13.Team == 'Fury'].TOs,  rug=True)

# %%
sns.distplot(stats_13[stats_13.Team == 'Riot'].Ds,  rug=True)

# %%
sns.distplot(stats_13[stats_13.Team == 'Riot'].TOs,  rug=True)

# %%
sns.jointplot("Goals","Assists",data=stats_13[stats_13.Team == 'Fury'], kind='kde')

# %%
sns.jointplot("Goals","Assists",data=stats_13[stats_13.Team == 'Riot'], kind='kde')

# %%
sns.jointplot("Goals","Assists",data=stats_13[stats_13.Team == 'Scandal'], kind='kde')

# %%
# stats_15[stats_15.Team == 'Fury'].Goals.plot(kind="hist")
sns.distplot(stats_15[stats_15.Team == 'Fury'].Goals,  rug=True)

# %%
# stats_15[stats_15.Team == 'Scandal'].Goals.plot(kind="hist")
sns.distplot(stats_15[stats_15.Team == 'Scandal'].Goals,  rug=True)

# %%
# stats_14[stats_14.Team == 'Fury'].Goals.plot(kind="hist")
sns.distplot(stats_14[stats_14.Team == 'Fury'].Goals,  rug=True)

# %%
# stats_14[stats_14.Team == 'Scandal'].Goals.plot(kind="hist")
sns.distplot(stats_14[stats_14.Team == 'Scandal'].Goals,  rug=True)

# %%
sns.jointplot("Goals","Assists",data=stats_14[stats_14.Team == 'Fury'], kind='kde')

# %%
sns.jointplot("Goals","Assists",data=stats_14[stats_14.Team == 'Scandal'], kind='kde')

# %%
sns.jointplot("Goals","Assists",data=stats_14[stats_14.Team == 'Riot'], kind='kde')

# %%
sns.jointplot("Goals","Assists",data=stats_15[stats_15.Team == 'Fury'], kind='kde')

# %%
sns.jointplot("Goals","Assists",data=stats_15[stats_15.Team == 'Scandal'], kind='kde')

# %%
sns.jointplot("Goals","Assists",data=stats_15[stats_15.Team == 'Seattle Riot'], kind='kde')

# %%
stats_14.Team.value_counts()
# Out:
# Green Means Go    27
# Heist             27
# Showdown          26
# Fury              26
# Riot              26
# Nightlock         26
# Brute Squad       26
# Schwa             25
# Scandal           24
# Traffic           24
# Underground       24
# Molly Brown       23
# Capitals          23
# Nemesis           23
# Ozone             22
# Tabby Rosa        19
# Name: Team, dtype: int64

# %%
stats_14['Team_num'] = stats_14.Team.map({'Fury':0, 'Riot':1, 'Scandal':2})

# %%
from matplotlib import colors

# create a custom color scale
col_map = colors.ListedColormap(['white', 'red',"blue"])

# create a scatter plot of PETAL LENGTH versus PETAL WIDTH and color by SPECIES
stats_14[(stats_14.Team == 'Fury') | (stats_14.Team == 'Riot') | (stats_14.Team == 'Scandal')].plot(kind="scatter",x="Goals",y="Assists",c="Team",cmap=col_map)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-6712bf423823> in <module>()
#       5
#       6 # create a scatter plot of PETAL LENGTH versus PETAL WIDTH and color by SPECIES
# ----> 7 stats_14[(stats_14.Team == 'Fury') | (stats_14.Team == 'Riot') | (stats_14.Team == 'Scandal')].plot(kind="scatter",x="Goals",y="Assists",c="Team",cmap=col_map)
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     985         self._compute_plot_data()
#     986         self._setup_subplots()
# --> 987         self._make_plot()
#     988         self._add_table()
#     989         self._make_legend()
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1557             label = None
#    1558         scatter = ax.scatter(data[x].values, data[y].values, c=c_values,
# -> 1559                              label=label, cmap=cmap, **self.kwds)
#    1560         if cb:
#    1561             img = ax.collections[0]
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3887                 offsets=offsets,
#    3888                 transOffset=kwargs.pop('transform', self.transData),
# -> 3889                 alpha=alpha
#    3890                 )
#    3891         collection.set_transform(mtransforms.IdentityTransform())
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     829         """
#     830
# --> 831         Collection.__init__(self, **kwargs)
#     832         self.set_paths(paths)
#     833         self.set_sizes(sizes)
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     115
#     116         self.set_edgecolor(edgecolors)
# --> 117         self.set_facecolor(facecolors)
#     118         self.set_linewidth(linewidths)
#     119         self.set_linestyle(linestyles)
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in set_facecolor(self, c)
#     610             c = mpl.rcParams['patch.facecolor']
#     611         self._facecolors_original = c
# --> 612         self._facecolors = mcolors.colorConverter.to_rgba_array(c, self._alpha)
#     613         self.stale = True
#     614
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba_array(self, c, alpha)
#     420             result = np.zeros((nc, 4), dtype=np.float)
#     421             for i, cc in enumerate(c):
# --> 422                 result[i] = self.to_rgba(cc, alpha)
#     423             return result
#     424
#
# /Users/octaviapayne/anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba(self, arg, alpha)
#     374         except (TypeError, ValueError) as exc:
#     375             raise ValueError(
# --> 376                 'to_rgba: Invalid rgba arg "%s"\n%s' % (str(arg), exc))
#     377
#     378     def to_rgba_array(self, c, alpha=None):
#
# ValueError: to_rgba: Invalid rgba arg "T"
# to_rgb: Invalid rgb arg "T"
# could not convert string to float: t

# %%
# might consider stats averaged per game to account for teams that have more games
