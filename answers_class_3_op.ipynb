# %% [markdown]
# ## Part 1
# Read in the file with csv.reader() and store it in an object called 'file_nested_list'.
#
# Hint: This is a TSV file, and csv.reader() needs to be told how to handle it.
#       https://docs.python.org/2/library/csv.html

# %%
cd ../DAT-DC-10/data/
# Out:
# /Users/octaviapayne/Desktop/DAT-DC-10/data

# %%
import csv
with open('chipotle.tsv','rU') as csvfile:
    file_nested_list = [row for row in csv.reader(csvfile, delimiter="\t")]

# %%
file_nested_list
# Out:
# [['order_id', 'quantity', 'item_name', 'choice_description', 'item_price'],
#  ['1', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 '],
#  ['1', '1', 'Izze', '[Clementine]', '$3.39 '],
#  ['1', '1', 'Nantucket Nectar', '[Apple]', '$3.39 '],
#  ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['2',
#   '2',
#   'Chicken Bowl',
#   '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#   '$16.98 '],
#  ['3',
#   '1',
#   'Chicken Bowl',
#   '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$10.98 '],
#  ['3', '1', 'Side of Chips', 'NULL', '$1.69 '],
#  ['4',
#   '1',
#   'Steak Burrito',
#   '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$11.75 '],
#  ['4',
#   '1',
#   'Steak Soft Tacos',
#   '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   '$9.25 '],
#  ['5',
#   '1',
#   'Steak Burrito',
# ...

# %% [markdown]
# ## Part 2
# Separate 'file_nested_list' into the 'header' and the 'data'.

# %%
header = file_nested_list[0]
data = file_nested_list[1:]

# %% [markdown]
# ## Part 3
# Calculate the average price of an order.
#
# Hint: Examine the data to see if the 'quantity' column is relevant to this calculation.
#
# Hint: Think carefully about the simplest way to do this!

# %%
#checking to see if quantity is ever >1
for item in data:
    if item[1] != '1':
        print item

#doesn't matter as item_price takes qty into account
# Out:
# ['2', '2', 'Chicken Bowl', '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]', '$16.98 ']
# ['9', '2', 'Canned Soda', '[Sprite]', '$2.18 ']
# ['23', '2', 'Canned Soda', '[Mountain Dew]', '$2.18 ']
# ['60', '2', 'Chicken Salad Bowl', '[Tomatillo Green Chili Salsa, [Sour Cream, Cheese, Guacamole]]', '$22.50 ']
# ['67', '2', 'Steak Burrito', '[Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese, Sour Cream, Lettuce]]', '$17.98 ']
# ['68', '2', 'Chicken Burrito', '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce]]', '$17.50 ']
# ['70', '2', 'Chicken Bowl', '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Lettuce]]', '$17.50 ']
# ['73', '2', 'Canned Soda', '[Diet Coke]', '$2.18 ']
# ['76', '2', 'Canned Soda', '[Diet Dr. Pepper]', '$2.18 ']
# ['94', '2', 'Chicken Salad Bowl', '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole]]', '$22.50 ']
# ...

# %%
#count number of unique order_id's
total_number_of_orders = int(data[-1][0])

#print to make sure above code worked
print total_number_of_orders
# Out:
# 1834

# %%
# create a list of prices, slice to remove '$' and change to type float
# note: ignore the 'quantity' column because the 'item_price' takes quantity into account
prices = [float(row[-1][1:-1]) for row in data]

#print to make sure above worked
print prices
# Out:
# [2.39, 3.39, 3.39, 2.39, 16.98, 10.98, 1.69, 11.75, 9.25, 9.25, 4.45, 8.75, 8.75, 11.25, 4.45, 2.39, 8.49, 8.49, 2.18, 8.75, 4.45, 8.99, 3.39, 10.98, 3.39, 2.39, 8.49, 8.99, 1.09, 8.49, 2.39, 8.99, 1.69, 8.99, 1.09, 8.75, 8.75, 4.45, 2.95, 11.75, 2.15, 4.45, 11.25, 11.75, 8.75, 10.98, 8.99, 3.39, 8.99, 3.99, 8.99, 2.18, 10.98, 1.09, 8.99, 2.39, 9.25, 11.25, 11.75, 2.15, 4.45, 9.25, 11.25, 8.75, 8.99, 8.99, 3.39, 8.99, 10.98, 8.99, 1.69, 8.99, 3.99, 8.75, 4.45, 8.75, 8.75, 2.15, 8.75, 11.25, 2.15, 9.25, 8.75, 8.75, 9.25, 8.49, 8.99, 1.09, 9.25, 2.95, 11.75, 11.75, 9.25, 11.75, 4.45, 9.25, 4.45, 11.75, 8.75, 8.75, 4.45, 8.99, 8.99, 3.99, 8.49, 3.39, 8.99, 1.09, 9.25, 4.45, 8.75, 2.95, 4.45, 2.39, 8.49, 8.99, 8.49, 1.09, 8.99, 3.99, 8.75, 9.25, 4.45, 11.25, 4.45, 8.99, 1.09, 9.25, 2.95, 4.45, 11.75, 4.45, 8.49, 2.39, 10.98, 22.5, 11.75, 4.45, 11.25, 4.45, 11.25, 4.45, 11.25, 11.25, 11.75, 9.25, 4.45, 11.48, 17.98, 1.69, 17.5, 4.45, 8.49, 2.39, 17.5, 4.45, 4.45, 11.25, 11.75, 10.98, 8.49
# ...

# %%
# calculate the average price of an order and round to 2 digits
avg_price_of_order = round((sum(prices)/total_number_of_orders),2)

#print to make sure above code worked
print avg_price_of_order
# Out:
# 18.81

# %%
#combined in one line
avg_price_of_order = round((sum([float(row[-1][1:-1]) for row in data])/int(data[-1][0])), 2)

#print answer
print "\nAverage price of an order is $" + str(avg_price_of_order)
# Out:
# Average price of an order is $18.81

# %% [markdown]
# ## Part 4
# Create a list (or set) of all unique sodas and soft drinks that they sell.
#
# Note: Just look for 'Canned Soda' and 'Canned Soft Drink', and ignore other drinks like 'Izze'.

# %%
#I think this answer was accidentally included in the hw
# use a for loop to get a list of all the sodas
sodas = []
for row in data:
    if 'Canned' in row[2]:
        sodas.append(row[3][1:-1])      # strip the brackets

# for practice, use a list comprehension to do the same
sodas = [row[3][1:-1] for row in data if 'Canned' in row[2]]

# now use the set() function to get just the unique elements of the list
unique_sodas = set(sodas)

print unique_sodas
# Out:
# set(['Sprite', 'Coke', 'Lemonade', 'Coca Cola', 'Diet Dr. Pepper', 'Diet Coke', 'Dr. Pepper', 'Nestea', 'Mountain Dew'])

# %% [markdown]
# ## Part 5
# Calculate the average number of toppings per burrito.
#
# Note: Let's ignore the 'quantity' column to simplify this task.
#
# Hint: Think carefully about the easiest way to count the number of toppings!

# %%
# keep a running total of burritos and toppings, so initalize some counter variables
# calculate number of toppings by counting the commas and adding 1
# note: x += 1 is equivalent to x = x + 1
# loop over the data and update the counters in this way

total_number_of_burritos = 0
for row in data:
    if 'Burrito' in row[2]:
        total_number_of_burritos += 1
        
total_burrito_toppings = 0
for row in data:
    if 'Burrito' in row[2]:
        total_burrito_toppings += (row[3].count(',') + 1)

print total_number_of_burritos
print total_burrito_toppings
# Out:
# 1172
# 6323

# %%
#combine to clean up code
total_number_of_burritos = 0
total_burrito_toppings = 0

for row in data:
    if 'Burrito' in row[2]:
        total_number_of_burritos += 1
        #why can't we do len(row[3])?
        total_burrito_toppings += (1 + row[3].count(','))

print total_number_of_burritos
print total_burrito_toppings
# Out:
# 1172
# 6323

# %%
# calculate the average topping count and round to 2 digits
#why can't we wrap the entire equation in float()?

avg_toppings_per_burrito = round(float(total_burrito_toppings)/total_number_of_burritos, 2)
print avg_toppings_per_burrito
# Out:
# 5.4

# %%
#list comprehension
total_number_of_burritos = sum(1 for row in data if 'Burrito' in row[2])
total_burrito_toppings = sum((1+row[3].count(',')) for row in data if 'Burrito' in row[2])
round((float(total_burrito_toppings)/total_number_of_burritos),2)
# Out:
# 5.4

# %% [markdown]
# ## Part 6
# Create a dictionary in which the keys represent chip orders and
#   the values represent the total number of orders.
#
# Expected output: {'Chips and Roasted Chili-Corn Salsa': 18, ... }
#
# Note: Please take the 'quantity' column into account!
#
# Optional: Learn how to use 'defaultdict' to simplify your code.

# %%
chips = {}

for row in data:
    if 'Chips' in row[2]:
        #i did the opposite of what was in the answers
        #either obviously works, but i see how the code in the answers is better
        if row[2] in chips:
            chips[row[2]] += int(row[1])
        else:
            chips[row[2]] = int(row[1])
        
chips
# Out:
# {'Chips': 230,
#  'Chips and Fresh Tomato Salsa': 130,
#  'Chips and Guacamole': 506,
#  'Chips and Mild Fresh Tomato Salsa': 1,
#  'Chips and Roasted Chili Corn Salsa': 23,
#  'Chips and Roasted Chili-Corn Salsa': 18,
#  'Chips and Tomatillo Green Chili Salsa': 45,
#  'Chips and Tomatillo Red Chili Salsa': 50,
#  'Chips and Tomatillo-Green Chili Salsa': 33,
#  'Chips and Tomatillo-Red Chili Salsa': 25,
#  'Side of Chips': 110}
