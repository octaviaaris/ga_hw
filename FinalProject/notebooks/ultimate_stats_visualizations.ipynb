# %% [markdown]
# ## Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
us_stat = pd.read_csv('../data/us_stat.csv')

# %%
us_stat = us_stat.iloc[:,1:]

# %%
# us_stat

# %%
col_map = colors.ListedColormap(['white', 'red'])
us_stat.plot(kind='scatter', x='GPG', y='APG', c='wg13', cmap=col_map)

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)
ax.scatter(us_stat.GPG, us_stat.APG, 50, c=us_stat.wg13, marker='o', cmap=col_map)
# Add some axis labels.
ax.set_xlabel("GPG")
ax.set_ylabel("APG")

# %%
fig.set_size_inches(10,10)
fig.savefig('GPAvsAPG.png', dpi=200)

# %%
x_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].groupby('Name').mean().GPG
y_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].groupby('Name').mean().APG
c_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].groupby('Name').mean().wg13

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x_data, y_data, 10, c=c_data, marker='o', cmap=col_map)
# Add some axis labels.
ax.set_xlabel("GPG")
ax.set_ylabel("APG")

# %%
# fig.set_size_inches(10,10)
fig.savefig('GPAvsAPG.png', dpi=200)

# %%
us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA') & (us_stat.wg13 ==1)].dropna().groupby('Name').mean()
# Out:
#                      Number       Goal       GPG     Assist       APG  \
# Name
# ALEX SNYDER        4.000000   2.000000  0.253968  17.000000  2.063492
# ANNA NAZAROV      33.000000   4.500000  0.611111   3.500000  0.452381
# CARA CROUCH        9.333333   4.333333  0.571429  14.333333  1.910714
# CREE HOWARD       13.000000   8.500000  1.023810   3.500000  0.404762
# GEORGIA BOSSCHER  19.000000   4.000000  0.666667   4.000000  0.666667
# OCTAVIA PAYNE      9.000000   4.000000  0.507937  14.000000  1.703704
# ROHRE TITCOMB      4.000000   0.333333  0.037037   3.666667  0.412037
# SANDY JORGENSEN   37.000000  11.500000  1.468254   8.000000  1.031746
# SARAH GRIFFITH     6.000000   9.666667  1.200397   9.333333  1.249339
#
#                       Block       BPG       Turn       TPG     Games  \
# Name
# ALEX SNYDER        6.000000  0.777778  10.500000  1.309524  8.000000
# ANNA NAZAROV       4.000000  0.555556   6.000000  0.777778  8.000000
# ...

# %%
x_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].dropna().groupby('Name').mean().BPG
y_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].dropna().groupby('Name').mean().TPG
c_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].dropna().groupby('Name').mean().wg13

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x_data, y_data, 10, c=c_data, marker='o', cmap=col_map)
# Add some axis labels.
ax.set_xlabel("BPG")
ax.set_ylabel("TPG")

# %%
fig.savefig('BPAvsTPG.png', dpi=200)

# %%
x_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].dropna().groupby('Name').mean().BPG
y_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].dropna().groupby('Name').mean().APG
c_data = us_stat[(us_stat.year <=2013) & (us_stat.Team !='TEAM USA')].dropna().groupby('Name').mean().fury

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x_data, y_data, 10, c=c_data, marker='o', cmap=col_map)
# Add some axis labels.
ax.set_xlabel("Standing")
ax.set_ylabel("Spirit")

# %%
us_stat[(us_stat.year <=2013)].groupby('Team').count()
# Out:
#              Number  Name  Goal  GPG  Assist  APG  Block  BPG  Turn  TPG  \
# Team
# BENT             49    49    49   49      49   49     25   25    25   25
# BRUTE SQUAD      51    51    51   51      51   51     26   26    26   26
# DESOTO           18    18    18   18      18   18      0    0     0    0
# FURTHER          16    16    16   16      16   16      0    0     0    0
# FURY            101   101   101  101     101  101     50   50    50   50
# HEIST            24    24    24   24      24   24     24   24    24   24
# MOLLY BROWN      78    78    78   78      78   78     52   52    52   52
# NEMESIS          47    47    47   47      47   47     24   24    24   24
# NIGHTLOCK        25    25    25   25      25   25     25   25    25   25
# OZONE            68    68    68   68      68   68     41   41    41   41
# PHOENIX          96    96    96   96      96   96     69   69    69   69
# REVOLOUTION      23    23    23   23      23   23      0    0     0    0
# ...

# %%
plt.scatter(us_stat.APG, us_stat.wg13)
plt.xlabel('APG')
plt.ylabel('wg13')

# %%
plt.scatter(us_stat.BPG, us_stat.wg13)
plt.xlabel('BPG')
plt.ylabel('wg13')

# %%
plt.scatter(us_stat.Standing, us_stat.wg13)
plt.xlabel('Standing')
plt.ylabel('wg13')

# %%
us_stat[us_stat.Team == 'FURY'].plot(kind='scatter', x='GPG', y='APG', color='blue')
us_stat[us_stat.Team == 'RIOT'].plot(kind='scatter', x='GPG', y='APG', color='white')
us_stat[us_stat.wg13 == 1].groupby('Name').mean().plot(kind='scatter', x='GPG', y='APG', color='red')

# %%
# plt.scatter(x=player_stats[player_stats.Team == 'FURY'].GPG, y=player_stats[player_stats.Team == 'FURY'].APG, color='red')
# plt.scatter(x=player_stats[player_stats.Team == 'RIOT'].GPG, y=player_stats[player_stats.Team == 'RIOT'].APG, color='white')
plt.scatter(x=us_stat[(us_stat.Team != 'FURY') & (us_stat.Team != 'RIOT')].GPG, y=us_stat[(us_stat.Team != 'FURY') & (us_stat.Team != 'RIOT')].APG, color='yellow')
plt.scatter(x=us_stat[us_stat.Team == 'FURY'].GPG, y=us_stat[us_stat.Team == 'FURY'].APG, color='red')
plt.scatter(x=us_stat[us_stat.Team == 'RIOT'].GPG, y=us_stat[us_stat.Team == 'RIOT'].APG, color='white')
plt.scatter(x=us_stat[us_stat.wg13 == 1].groupby('Name').mean().GPG, y=us_stat[us_stat.wg13 == 1].groupby('Name').mean().APG, color='blue')

# %%
clean_stats = us_stat.dropna()

# %%
# BPG for wg13 players vs. non
sns.boxplot(x="wg13", y="BPG", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %%
sns.boxplot(x="riot", y="BPG", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %%
# Blocks for wg13 players vs. non
sns.boxplot(x="wg13", y="Block", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %% [markdown]
# Defensively focused team. Generates more blocks and blocks per game than rest of the field.

# %%
# Turns for wg13 players vs. non
sns.boxplot(x="wg13", y="Goal", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %%
# Turns for wg13 players vs. non
sns.boxplot(x="wg13", y="GPG", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %%
# TPG for wg13 players vs. non
sns.boxplot(x="wg13", y="APG", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %%
# Turns for wg13 players vs. non
sns.boxplot(x="wg13", y="Assist", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %% [markdown]
# Fewer outliers in turns on WG13, but generally higher TOs than rest of the field. Possibly because players are defensively focused, they are weaker on O, OR players touch the disc more on their respective teams and therefore have more opportunities to turn.

# %%
# Standing for wg13 players vs. non
sns.boxplot(x="wg13", y="Standing", data=us_stat[(us_stat.year <=2013) & (us_stat.Team != 'TEAM USA')].groupby('Name').mean())

# %% [markdown]
# All players on WG13, except one, played on club teams that finished in the top 4.
#
# **Hypothesis:** Playing on top teams develops players and gives them better chance of making Team USA. Georgia, who was the outlier, played on Fury two prior years.

# %%
sns.boxplot(x="fury", y="BPG", data=us_stat)

# %%
sns.boxplot(x="fury", y="Block", data=us_stat)

# %%
sns.boxplot(x="fury", y="APG", data=us_stat)

# %%
# BPG for wg13 players vs. non
sns.boxplot(x="fury", y="Assist", data=us_stat)

# %%
# BPG for wg13 players vs. non
sns.boxplot(x="riot", y="BPG", data=clean_stats)

# %%
# BPG for wg13 players vs. non
sns.boxplot(x="riot", y="Block", data=us_stat)

# %%
# BPG for wg13 players vs. non
sns.boxplot(x="riot", y="APG", data=us_stat)

# %%
# BPG for wg13 players vs. non
sns.boxplot(x="riot", y="Assist", data=us_stat)
