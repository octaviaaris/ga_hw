# %% [markdown]
# ## Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
player_stats = pd.read_csv('../data/player_stats.csv')

# %%
player_stats.plot(kind='scatter', x='GPG', y='APG')

# %%
player_stats[player_stats.wg13 ==1].plot(kind='scatter', x='GPG', y='APG')

# %%
# APG for wg13 players vs. non
sns.boxplot(x="wg13", y="APG", data=player_stats)

# %%
# GPG for wg13 players vs. non
sns.boxplot(x="wg13", y="GPG", data=player_stats)

# %%
us_stats[(us_stats.Team == 'FURY') | (us_stats.Team == 'RIOT')].plot(kind='scatter', x='GPG', y='APG', c='Team_Num', colormap='Accent')
us_stats.plot(kind='scatter', x='Goal', y='Assist', c='Team_Num', colormap='Accent')
